# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
march = pd.read_spss("/Pathways March 2020 (ATP W63.5)/Pathways Mar 2020 (ATP W63.5).sav")
nov = pd.read_spss("/users/milliebrooks/downloads/Pathways Nov 2020 (ATP W79)/Pathways Nov 2020 (ATP W79).sav")
print(march.shape)
print(nov.shape)

[c for c in march.columns if "COVID" in c]
[c for c in march.columns if "PARTY" in c]
# Out:
# ---------------------------------------------------------------------------
# PyreadstatError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 march = pd.read_spss("/Pathways March 2020 (ATP W63.5)/Pathways Mar 2020 (ATP W63.5).sav")
#       2 nov = pd.read_spss("/users/milliebrooks/downloads/Pathways Nov 2020 (ATP W79)/Pathways Nov 2020 (ATP W79).sav")
#       3 print(march.shape)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/spss.py:66, in read_spss(path, usecols, convert_categoricals, dtype_backend)
#      63         raise TypeError("usecols must be list-like.")
#      64     usecols = list(usecols)  # pyreadstat requires a list
# ---> 66 df, metadata = pyreadstat.read_sav(
#      67     stringify_path(path), usecols=usecols, apply_value_formats=convert_categoricals
#      68 )
#      69 df.attrs = metadata.__dict__
#      70 if dtype_backend is not lib.no_default:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pyreadstat/pyreadstat.py:687, in read_sav(filename_path, metadataonly, dates_as_pandas_datetime, apply_value_formats, formats_as_category, formats_as_ordered_category, encoding, usecols, user_missing, disable_datetime_conversion, row_limit, row_offset, output_format, extra_datetime_formats, extra_date_formats, extra_time_formats)
#     625 r"""
#     626 Read a SPSS sav or zsav (compressed) files
#     627
#    (...)    683         object with metadata. Look at the documentation for more information.
#     684 """
#     685 parser_format = "sav/zsav"
# --> 687 data_frame, metadata = parser_entry_point(
#     688     filename_path,
#     689     parser_format=parser_format,
#     690     metadataonly=metadataonly,
#     691     dates_as_pandas_datetime=dates_as_pandas_datetime,
#     692     formats_as_category=formats_as_category,
#     693     formats_as_ordered_category=formats_as_ordered_category,
#     694     encoding=encoding,
#     695     usecols=usecols,
#     696     user_missing=user_missing,
#     697     disable_datetime_conversion=disable_datetime_conversion,
#     698     row_limit=row_limit,
#     699     row_offset=row_offset,
#     700     output_format=output_format,
#     701     extra_datetime_formats=extra_datetime_formats,
#     702     extra_date_formats=extra_date_formats,
#     703     extra_time_formats=extra_time_formats,
#     704 )
#     706 metadata.file_format = parser_format
#     708 if apply_value_formats:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pyreadstat/_readstat_parser.pyx:1411, in pyreadstat._readstat_parser.parser_entry_point()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pyreadstat/_readstat_parser.pyx:1267, in pyreadstat._readstat_parser.run_conversion()
#
# PyreadstatError: File /Pathways March 2020 (ATP W63.5)/Pathways Mar 2020 (ATP W63.5).sav does not exist!

# %%
import os
os.getcwd()

os.listdir("../data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 import os
#       2 os.getcwd()
# ----> 4 os.listdir("../data")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data'

# %%
march["COVIDMISINFO_W63.5"].value_counts(dropna=False)
#march["COVIDCREATE_W63.5"].value_counts(dropna=False)

# %%
march["F_PARTYSUM_FINAL"].value_counts(dropna=False)

# %%
[c for c in nov.columns if "ELECT" in c]
[c for c in nov.columns if "MISINFO" in c]

nov["CAMP20MISINFO_W79"].value_counts(dropna=False)
#nov["MISINFOIMPACT_b_W79"].value_counts(dropna=False)

# %%
march["QKEY"].head()
nov["QKEY"].head()
march["QKEY"].isin(nov["QKEY"]).sum()

# %%
march_clean = march[["QKEY",
                     "COVIDMISINFO_W63.5",
                     "COVIDCREATE_W63.5",
                     "F_PARTYSUM_FINAL",
                     "F_IDEO",
                     "F_AGECAT",
                     "F_EDUCCAT",
                     "WEIGHT_W63.5"]]

nov_clean = nov[["QKEY",
                 "CAMP20MISINFO_W79",
                 "MISINFOSELF_W79",
                 "MISINFOIMPACT_a_W79",
                 "MISINFOIMPACT_b_W79",
                 "MISINFOIMPACT_c_W79"]]

# %%
post = pd.read_spss("/users/milliebrooks/downloads/W78_Nov20/ATP W78.sav")
post.head()
#[c for c in post.columns if "VOTE" in c]
#post["VOTEGEN_POST_W78"].value_counts(dropna=False)
march["QKEY"].isin(post["QKEY"]).sum()

# %%
post_clean = post[["QKEY", "VOTEGEN_POST_W78"]]
